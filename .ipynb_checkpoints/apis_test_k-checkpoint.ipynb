# %%
import requests
import pandas as pd
import json
from PIL import Image
from pandas.io.json import json_normalize

# %%
response=requests.get('https://restcountries.eu/rest/v2/all')

# %%
status=response.status_code
status
# Out:
# 200

# %%
d=response.json()

# %%
df=json_normalize(d)
df.shape[0]
# Out:
# 250

# %%
df.rename(columns={'name':'country'},inplace=True)
df.drop(['topLevelDomain','alpha2Code','alpha3Code','altSpellings','numericCode','translations.de', 'translations.es',
       'translations.fr', 'translations.ja', 'translations.it',
       'translations.br', 'translations.pt', 'translations.nl',
       'translations.hr', 'translations.fa'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           country callingCodes    capital   region        subregion  \
# 0     Afghanistan         [93]      Kabul     Asia    Southern Asia
# 1   Åland Islands        [358]  Mariehamn   Europe  Northern Europe
# 2         Albania        [355]     Tirana   Europe  Southern Europe
# 3         Algeria        [213]    Algiers   Africa  Northern Africa
# 4  American Samoa       [1684]  Pago Pago  Oceania        Polynesia
#
#    population                  latlng          demonym       area  gini  \
# 0    27657145            [33.0, 65.0]           Afghan   652230.0  27.8
# 1       28875       [60.116667, 19.9]         Ålandish     1580.0   NaN
# 2     2886026            [41.0, 20.0]         Albanian    28748.0  34.5
# 3    40400000             [28.0, 3.0]         Algerian  2381741.0  35.3
# 4       57100  [-14.33333333, -170.0]  American Samoan      199.0   NaN
#
#      timezones                              borders      nativeName  \
# 0  [UTC+04:30]       [IRN, PAK, TKM, UZB, TJK, CHN]       افغانستان
# 1  [UTC+02:00]                                   []           Åland
# 2  [UTC+01:00]                 [MNE, GRC, MKD, KOS]       Shqipëria
# 3  [UTC+01:00]  [TUN, LBY, NER, ESH, MRT, MLI, MAR]         الجزائر
# 4  [UTC-11:00]                                   []  American Samoa
#
#                                           currencies  \
# 0  [{'code': 'AFN', 'name': 'Afghan afghani', 'sy...
# 1   [{'code': 'EUR', 'name': 'Euro', 'symbol': '€'}]
# 2  [{'code': 'ALL', 'name': 'Albanian lek', 'symb...
# 3  [{'code': 'DZD', 'name': 'Algerian dinar', 'sy...
# 4  [{'code': 'USD', 'name': 'United State Dollar'...
#
#                                            languages  \
# 0  [{'iso639_1': 'ps', 'iso639_2': 'pus', 'name':...
# 1  [{'iso639_1': 'sv', 'iso639_2': 'swe', 'name':...
# 2  [{'iso639_1': 'sq', 'iso639_2': 'sqi', 'name':...
# 3  [{'iso639_1': 'ar', 'iso639_2': 'ara', 'name':...
# 4  [{'iso639_1': 'en', 'iso639_2': 'eng', 'name':...
#
#                                     flag  \
# 0  https://restcountries.eu/data/afg.svg
# 1  https://restcountries.eu/data/ala.svg
# 2  https://restcountries.eu/data/alb.svg
# 3  https://restcountries.eu/data/dza.svg
# 4  https://restcountries.eu/data/asm.svg
#
#                                        regionalBlocs cioc
# 0  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  AFG
# 1  [{'acronym': 'EU', 'name': 'European Union', '...
# 2  [{'acronym': 'CEFTA', 'name': 'Central Europea...  ALB
# 3  [{'acronym': 'AU', 'name': 'African Union', 'o...  ALG
# 4                                                 []  ASA

# %%
df.columns
# Out:
# Index(['country', 'callingCodes', 'capital', 'region', 'subregion',
#        'population', 'latlng', 'demonym', 'area', 'gini', 'timezones',
#        'borders', 'nativeName', 'currencies', 'languages', 'flag',
#        'regionalBlocs', 'cioc'],
#       dtype='object')

# %%
def languages(col):
    lang=[]
    for i in range(0,len(col)):
        tab=pd.Series(col[i])
        tab=json_normalize(tab)
        name=tab['name'].tolist()
        lang.append(name)
    return lang

# %%
a=df['languages']
b=languages(a)
df['languages']=b

# %%
df['languages']
# Out:
# 0                [Pashto, Uzbek, Turkmen]
# 1                               [Swedish]
# 2                              [Albanian]
# 3                                [Arabic]
# 4                       [English, Samoan]
#                       ...
# 245                              [French]
# 246                             [Spanish]
# 247                              [Arabic]
# 248                             [English]
# 249    [English, Shona, Northern Ndebele]
# Name: languages, Length: 250, dtype: object

# %%
def currencies(col):
    curr=[]
    for i in range(0,len(col)):
        tab=pd.Series(col[i])
        tab=json_normalize(tab)
        name=tab['name'].tolist()
        curr.append(name)
    return curr

# %%
c=df['currencies']
d=currencies(c)
df['currencies']=d

# %%
df['currencies']
# Out:
# 0                                       [Afghan afghani]
# 1                                                 [Euro]
# 2                                         [Albanian lek]
# 3                                       [Algerian dinar]
# 4                                  [United State Dollar]
#                              ...
# 245                                          [CFP franc]
# 246                    [Moroccan dirham, Algerian dinar]
# 247                                        [Yemeni rial]
# 248                                     [Zambian kwacha]
# 249    [Botswana pula, British pound, Chinese yuan, E...
# Name: currencies, Length: 250, dtype: object

# %%
def blocs(col):
    bloc=[]
    for i in range(0,len(col)):
        tab=pd.Series(col[i])
        tab=json_normalize(tab)
        name=tab['name']
        bloc.append(name)
    return bloc

# %%
re=df['regionalBlocs']
tab=blocs(re)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-a5a6cb6d0d5b> in <module>
#       1 re=df['regionalBlocs']
# ----> 2 tab=blocs(re)
#
# <ipython-input-42-374ae93af8e8> in blocs(col)
#       4         tab=pd.Series(col[i])
#       5         tab=json_normalize(tab)
# ----> 6         name=tab['name']
#       7         bloc.append(name)
#       8     return bloc
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     377             except ValueError:
#     378                 raise KeyError(key)
# --> 379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#     381     @Appender(_index_shared_docs["get_indexer"])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'name'

# %%
df.head()
# Out:
#           country callingCodes    capital   region        subregion  \
# 0     Afghanistan         [93]      Kabul     Asia    Southern Asia
# 1   Åland Islands        [358]  Mariehamn   Europe  Northern Europe
# 2         Albania        [355]     Tirana   Europe  Southern Europe
# 3         Algeria        [213]    Algiers   Africa  Northern Africa
# 4  American Samoa       [1684]  Pago Pago  Oceania        Polynesia
#
#    population                  latlng          demonym       area  gini  \
# 0    27657145            [33.0, 65.0]           Afghan   652230.0  27.8
# 1       28875       [60.116667, 19.9]         Ålandish     1580.0   NaN
# 2     2886026            [41.0, 20.0]         Albanian    28748.0  34.5
# 3    40400000             [28.0, 3.0]         Algerian  2381741.0  35.3
# 4       57100  [-14.33333333, -170.0]  American Samoan      199.0   NaN
#
#      timezones                              borders      nativeName  \
# 0  [UTC+04:30]       [IRN, PAK, TKM, UZB, TJK, CHN]       افغانستان
# 1  [UTC+02:00]                                   []           Åland
# 2  [UTC+01:00]                 [MNE, GRC, MKD, KOS]       Shqipëria
# 3  [UTC+01:00]  [TUN, LBY, NER, ESH, MRT, MLI, MAR]         الجزائر
# 4  [UTC-11:00]                                   []  American Samoa
#
#               currencies                 languages  \
# 0       [Afghan afghani]  [Pashto, Uzbek, Turkmen]
# 1                 [Euro]                 [Swedish]
# 2         [Albanian lek]                [Albanian]
# 3       [Algerian dinar]                  [Arabic]
# 4  [United State Dollar]         [English, Samoan]
#
#                                     flag  \
# 0  https://restcountries.eu/data/afg.svg
# 1  https://restcountries.eu/data/ala.svg
# 2  https://restcountries.eu/data/alb.svg
# 3  https://restcountries.eu/data/dza.svg
# 4  https://restcountries.eu/data/asm.svg
#
#                                        regionalBlocs cioc
# 0  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  AFG
# 1  [{'acronym': 'EU', 'name': 'European Union', '...
# 2  [{'acronym': 'CEFTA', 'name': 'Central Europea...  ALB
# 3  [{'acronym': 'AU', 'name': 'African Union', 'o...  ALG
# 4                                                 []  ASA

# %%
dff=df.copy()

# %%
#Check each region has how many countries
dff['region'].value_counts()
# Out:
# Africa      60
# Americas    57
# Europe      53
# Asia        50
# Oceania     27
#              2
# Polar        1
# Name: region, dtype: int64

# %% [markdown]
# ### Analyzing asia countries

# %%
asia=dff[dff['region']=='Asia'].reset_index(drop=True)
asia
# Out:
#                                     country callingCodes              capital  \
# 0                               Afghanistan         [93]                Kabul
# 1                                   Armenia        [374]              Yerevan
# 2                                Azerbaijan        [994]                 Baku
# 3                                   Bahrain        [973]               Manama
# 4                                Bangladesh        [880]                Dhaka
# 5                                    Bhutan        [975]              Thimphu
# 6                         Brunei Darussalam        [673]  Bandar Seri Begawan
# 7                                  Cambodia        [855]           Phnom Penh
# 8                                     China         [86]              Beijing
# 9                                   Georgia        [995]              Tbilisi
# 10                                Hong Kong        [852]     City of Victoria
# 11                                    India         [91]            New Delhi
# 12                                Indonesia         [62]              Jakarta
# 13               Iran (Islamic Republic of)         [98]               Tehran
# 14                                     Iraq        [964]              Baghdad
# 15                                   Israel        [972]            Jerusalem
# 16                                    Japan         [81]                Tokyo
# 17                                   Jordan        [962]                Amman
# 18                               Kazakhstan     [76, 77]               Astana
# 19                                   Kuwait        [965]          Kuwait City
# 20                               Kyrgyzstan        [996]              Bishkek
# 21         Lao People's Democratic Republic        [856]            Vientiane
# 22                                  Lebanon        [961]               Beirut
# 23                                    Macao        [853]
# 24                                 Malaysia         [60]         Kuala Lumpur
# 25                                 Maldives        [960]                 Malé
# 26                                 Mongolia        [976]           Ulan Bator
# 27                                  Myanmar         [95]            Naypyidaw
# 28                                    Nepal        [977]            Kathmandu
# 29  Korea (Democratic People's Republic of)        [850]            Pyongyang
# 30                                     Oman        [968]               Muscat
# 31                                 Pakistan         [92]            Islamabad
# 32                      Palestine, State of        [970]             Ramallah
# 33                              Philippines         [63]               Manila
# 34                                    Qatar        [974]                 Doha
# 35                             Saudi Arabia        [966]               Riyadh
# 36                                Singapore         [65]            Singapore
# 37                      Korea (Republic of)         [82]                Seoul
# 38                                Sri Lanka         [94]              Colombo
# 39                     Syrian Arab Republic        [963]             Damascus
# 40                                   Taiwan        [886]               Taipei
# 41                               Tajikistan        [992]             Dushanbe
# 42                                 Thailand         [66]              Bangkok
# 43                              Timor-Leste        [670]                 Dili
# 44                                   Turkey         [90]               Ankara
# 45                             Turkmenistan        [993]             Ashgabat
# 46                     United Arab Emirates        [971]            Abu Dhabi
# 47                               Uzbekistan        [998]             Tashkent
# 48                                 Viet Nam         [84]                Hanoi
# 49                                    Yemen        [967]               Sana'a
#
#    region           subregion  population                       latlng  \
# 0    Asia       Southern Asia    27657145                 [33.0, 65.0]
# 1    Asia        Western Asia     2994400                 [40.0, 45.0]
# 2    Asia        Western Asia     9730500                 [40.5, 47.5]
# 3    Asia        Western Asia     1404900                [26.0, 50.55]
# 4    Asia       Southern Asia   161006790                 [24.0, 90.0]
# 5    Asia       Southern Asia      775620                 [27.5, 90.5]
# 6    Asia  South-Eastern Asia      411900          [4.5, 114.66666666]
# 7    Asia  South-Eastern Asia    15626444                [13.0, 105.0]
# 8    Asia        Eastern Asia  1377422166                [35.0, 105.0]
# 9    Asia        Western Asia     3720400                 [42.0, 43.5]
# 10   Asia        Eastern Asia     7324300        [22.25, 114.16666666]
# 11   Asia       Southern Asia  1295210000                 [20.0, 77.0]
# 12   Asia  South-Eastern Asia   258705000                [-5.0, 120.0]
# 13   Asia       Southern Asia    79369900                 [32.0, 53.0]
# 14   Asia        Western Asia    37883543                 [33.0, 44.0]
# 15   Asia        Western Asia     8527400                [31.5, 34.75]
# 16   Asia        Eastern Asia   126960000                [36.0, 138.0]
# 17   Asia        Western Asia     9531712                 [31.0, 36.0]
# 18   Asia        Central Asia    17753200                 [48.0, 68.0]
# 19   Asia        Western Asia     4183658                [29.5, 45.75]
# 20   Asia        Central Asia     6047800                 [41.0, 75.0]
# 21   Asia  South-Eastern Asia     6492400                [18.0, 105.0]
# 22   Asia        Western Asia     5988000   [33.83333333, 35.83333333]
# 23   Asia        Eastern Asia      649100        [22.16666666, 113.55]
# 24   Asia  South-Eastern Asia    31405416                 [2.5, 112.5]
# 25   Asia       Southern Asia      344023                 [3.25, 73.0]
# 26   Asia        Eastern Asia     3093100                [46.0, 105.0]
# 27   Asia  South-Eastern Asia    51419420                 [22.0, 98.0]
# 28   Asia       Southern Asia    28431500                 [28.0, 84.0]
# 29   Asia        Eastern Asia    25281000                [40.0, 127.0]
# 30   Asia        Western Asia     4420133                 [21.0, 57.0]
# 31   Asia       Southern Asia   194125062                 [30.0, 70.0]
# 32   Asia        Western Asia     4682467                 [31.9, 35.2]
# 33   Asia  South-Eastern Asia   103279800                [13.0, 122.0]
# 34   Asia        Western Asia     2587564                [25.5, 51.25]
# 35   Asia        Western Asia    32248200                 [25.0, 45.0]
# 36   Asia  South-Eastern Asia     5535000          [1.36666666, 103.8]
# 37   Asia        Eastern Asia    50801405                [37.0, 127.5]
# 38   Asia       Southern Asia    20966000                  [7.0, 81.0]
# 39   Asia        Western Asia    18564000                 [35.0, 38.0]
# 40   Asia        Eastern Asia    23503349                [23.5, 121.0]
# 41   Asia        Central Asia     8593600                 [39.0, 71.0]
# 42   Asia  South-Eastern Asia    65327652                [15.0, 100.0]
# 43   Asia  South-Eastern Asia     1167242  [-8.83333333, 125.91666666]
# 44   Asia        Western Asia    78741053                 [39.0, 35.0]
# 45   Asia        Central Asia     4751120                 [40.0, 60.0]
# 46   Asia        Western Asia     9856000                 [24.0, 54.0]
# 47   Asia        Central Asia    31576400                 [41.0, 64.0]
# 48   Asia  South-Eastern Asia    92700000  [16.16666666, 107.83333333]
# 49   Asia        Western Asia    27478000                 [15.0, 48.0]
#
#           demonym       area  gini                          timezones  \
# 0          Afghan   652230.0  27.8                        [UTC+04:30]
# 1        Armenian    29743.0  30.9                        [UTC+04:00]
# 2     Azerbaijani    86600.0  33.7                        [UTC+04:00]
# 3        Bahraini      765.0   NaN                        [UTC+03:00]
# 4     Bangladeshi   147570.0  32.1                        [UTC+06:00]
# 5       Bhutanese    38394.0  38.1                        [UTC+06:00]
# 6        Bruneian     5765.0   NaN                        [UTC+08:00]
# 7       Cambodian   181035.0  37.9                        [UTC+07:00]
# 8         Chinese  9640011.0  47.0                        [UTC+08:00]
# 9        Georgian    69700.0  41.3                        [UTC-05:00]
# 10        Chinese     1104.0  53.3                        [UTC+08:00]
# 11         Indian  3287590.0  33.4                        [UTC+05:30]
# 12     Indonesian  1904569.0  34.0  [UTC+07:00, UTC+08:00, UTC+09:00]
# 13        Iranian  1648195.0  38.3                        [UTC+03:30]
# 14          Iraqi   438317.0  30.9                        [UTC+03:00]
# 15        Israeli    20770.0  39.2                        [UTC+02:00]
# 16       Japanese   377930.0  38.1                        [UTC+09:00]
# 17      Jordanian    89342.0  35.4                        [UTC+03:00]
# 18    Kazakhstani  2724900.0  29.0             [UTC+05:00, UTC+06:00]
# 19        Kuwaiti    17818.0   NaN                        [UTC+03:00]
# 20        Kirghiz   199951.0  36.2                        [UTC+06:00]
# 21        Laotian   236800.0  36.7                        [UTC+07:00]
# 22       Lebanese    10452.0   NaN                        [UTC+02:00]
# 23        Chinese       30.0   NaN                        [UTC+08:00]
# 24      Malaysian   330803.0  46.2                        [UTC+08:00]
# 25       Maldivan      300.0  37.4                        [UTC+05:00]
# 26      Mongolian  1564110.0  36.5             [UTC+07:00, UTC+08:00]
# 27        Burmese   676578.0   NaN                        [UTC+06:30]
# 28       Nepalese   147181.0  32.8                        [UTC+05:45]
# 29   North Korean   120538.0   NaN                        [UTC+09:00]
# 30          Omani   309500.0   NaN                        [UTC+04:00]
# 31      Pakistani   881912.0  30.0                        [UTC+05:00]
# 32    Palestinian        NaN  35.5                        [UTC+02:00]
# 33       Filipino   342353.0  43.0                        [UTC+08:00]
# 34         Qatari    11586.0  41.1                        [UTC+03:00]
# 35  Saudi Arabian  2149690.0   NaN                        [UTC+03:00]
# 36    Singaporean      710.0  48.1                        [UTC+08:00]
# 37   South Korean   100210.0  31.3                        [UTC+09:00]
# 38     Sri Lankan    65610.0  40.3                        [UTC+05:30]
# 39         Syrian   185180.0  35.8                        [UTC+02:00]
# 40      Taiwanese    36193.0   NaN                        [UTC+08:00]
# 41        Tadzhik   143100.0  30.8                        [UTC+05:00]
# 42           Thai   513120.0  40.0                        [UTC+07:00]
# 43  East Timorese    14874.0  31.9                        [UTC+09:00]
# 44        Turkish   783562.0  39.0                        [UTC+03:00]
# 45        Turkmen   488100.0  40.8                        [UTC+05:00]
# 46        Emirati    83600.0   NaN                           [UTC+04]
# 47    Uzbekistani   447400.0  36.7                        [UTC+05:00]
# 48     Vietnamese   331212.0  35.6                        [UTC+07:00]
# 49         Yemeni   527968.0  37.7                        [UTC+03:00]
#
#                                               borders  \
# 0                      [IRN, PAK, TKM, UZB, TJK, CHN]
# 1                                [AZE, GEO, IRN, TUR]
# 2                           [ARM, GEO, IRN, RUS, TUR]
# 3                                                  []
# 4                                          [MMR, IND]
# 5                                          [CHN, IND]
# 6                                               [MYS]
# 7                                     [LAO, THA, VNM]
# 8   [AFG, BTN, MMR, HKG, IND, KAZ, PRK, KGZ, LAO, ...
# 9                                [ARM, AZE, RUS, TUR]
# 10                                              [CHN]
# 11           [AFG, BGD, BTN, MMR, CHN, NPL, PAK, LKA]
# 12                                    [TLS, MYS, PNG]
# 13                [AFG, ARM, AZE, IRQ, PAK, TUR, TKM]
# 14                     [IRN, JOR, KWT, SAU, SYR, TUR]
# 15                               [EGY, JOR, LBN, SYR]
# 16                                                 []
# 17                               [IRQ, ISR, SAU, SYR]
# 18                          [CHN, KGZ, RUS, TKM, UZB]
# 19                                         [IRN, SAU]
# 20                               [CHN, KAZ, TJK, UZB]
# 21                          [MMR, KHM, CHN, THA, VNM]
# 22                                         [ISR, SYR]
# 23                                              [CHN]
# 24                                    [BRN, IDN, THA]
# 25                                                 []
# 26                                         [CHN, RUS]
# 27                          [BGD, CHN, IND, LAO, THA]
# 28                                         [CHN, IND]
# 29                                    [CHN, KOR, RUS]
# 30                                    [SAU, ARE, YEM]
# 31                               [AFG, CHN, IND, IRN]
# 32                                    [ISR, EGY, JOR]
# 33                                                 []
# 34                                              [SAU]
# 35                [IRQ, JOR, KWT, OMN, QAT, ARE, YEM]
# 36                                                 []
# 37                                              [PRK]
# 38                                              [IND]
# 39                          [IRQ, ISR, JOR, LBN, TUR]
# 40                                                 []
# 41                               [AFG, CHN, KGZ, UZB]
# 42                               [MMR, KHM, LAO, MYS]
# 43                                              [IDN]
# 44           [ARM, AZE, BGR, GEO, GRC, IRN, IRQ, SYR]
# 45                               [AFG, IRN, KAZ, UZB]
# 46                                         [OMN, SAU]
# 47                          [AFG, KAZ, KGZ, TJK, TKM]
# 48                                    [KHM, CHN, LAO]
# 49                                         [OMN, SAU]
#
#                        nativeName                              currencies  \
# 0                       افغانستان                        [Afghan afghani]
# 1                        Հայաստան                         [Armenian dram]
# 2                      Azərbaycan                     [Azerbaijani manat]
# 3                        ‏البحرين                        [Bahraini dinar]
# 4                      Bangladesh                      [Bangladeshi taka]
# 5                       ʼbrug-yul      [Bhutanese ngultrum, Indian rupee]
# 6        Negara Brunei Darussalam       [Brunei dollar, Singapore dollar]
# 7                       Kâmpŭchéa  [Cambodian riel, United States dollar]
# 8                              中国                          [Chinese yuan]
# 9                      საქართველო                         [Georgian Lari]
# 10                             香港                      [Hong Kong dollar]
# 11                           भारत                          [Indian rupee]
# 12                      Indonesia                     [Indonesian rupiah]
# 13                          ایران                          [Iranian rial]
# 14                         العراق                           [Iraqi dinar]
# 15                     יִשְׂרָאֵל                    [Israeli new shekel]
# 16                             日本                          [Japanese yen]
# 17                         الأردن                       [Jordanian dinar]
# 18                      Қазақстан                     [Kazakhstani tenge]
# 19                         الكويت                         [Kuwaiti dinar]
# 20                     Кыргызстан                       [Kyrgyzstani som]
# 21                         ສປປລາວ                               [Lao kip]
# 22                          لبنان                        [Lebanese pound]
# 23                             澳門                       [Macanese pataca]
# 24                       Malaysia                     [Malaysian ringgit]
# 25                       Maldives                     [Maldivian rufiyaa]
# 26                     Монгол улс                      [Mongolian tögrög]
# 27                         Myanma                          [Burmese kyat]
# 28                          नेपाल                        [Nepalese rupee]
# 29                             북한                      [North Korean won]
# 30                           عمان                            [Omani rial]
# 31                       Pakistan                       [Pakistani rupee]
# 32                         فلسطين                    [Israeli new sheqel]
# 33                      Pilipinas                       [Philippine peso]
# 34                            قطر                          [Qatari riyal]
# 35               العربية السعودية                           [Saudi riyal]
# 36                      Singapore       [Brunei dollar, Singapore dollar]
# 37                           대한민국                      [South Korean won]
# 38                    śrī laṃkāva                      [Sri Lankan rupee]
# 39                          سوريا                          [Syrian pound]
# 40                             臺灣                     [New Taiwan dollar]
# 41                     Тоҷикистон                    [Tajikistani somoni]
# 42                      ประเทศไทย                             [Thai baht]
# 43                    Timor-Leste            [United States dollar, None]
# 44                        Türkiye                          [Turkish lira]
# 45                   Türkmenistan                    [Turkmenistan manat]
# 46  دولة الإمارات العربية المتحدة           [United Arab Emirates dirham]
# 47                    O‘zbekiston                      [Uzbekistani so'm]
# 48                       Việt Nam                       [Vietnamese đồng]
# 49                        اليَمَن                           [Yemeni rial]
#
#                            languages                                   flag  \
# 0           [Pashto, Uzbek, Turkmen]  https://restcountries.eu/data/afg.svg
# 1                [Armenian, Russian]  https://restcountries.eu/data/arm.svg
# 2                      [Azerbaijani]  https://restcountries.eu/data/aze.svg
# 3                           [Arabic]  https://restcountries.eu/data/bhr.svg
# 4                          [Bengali]  https://restcountries.eu/data/bgd.svg
# 5                         [Dzongkha]  https://restcountries.eu/data/btn.svg
# 6                            [Malay]  https://restcountries.eu/data/brn.svg
# 7                            [Khmer]  https://restcountries.eu/data/khm.svg
# 8                          [Chinese]  https://restcountries.eu/data/chn.svg
# 9                         [Georgian]  https://restcountries.eu/data/geo.svg
# 10                [English, Chinese]  https://restcountries.eu/data/hkg.svg
# 11                  [Hindi, English]  https://restcountries.eu/data/ind.svg
# 12                      [Indonesian]  https://restcountries.eu/data/idn.svg
# 13                 [Persian (Farsi)]  https://restcountries.eu/data/irn.svg
# 14                 [Arabic, Kurdish]  https://restcountries.eu/data/irq.svg
# 15         [Hebrew (modern), Arabic]  https://restcountries.eu/data/isr.svg
# 16                        [Japanese]  https://restcountries.eu/data/jpn.svg
# 17                          [Arabic]  https://restcountries.eu/data/jor.svg
# 18                 [Kazakh, Russian]  https://restcountries.eu/data/kaz.svg
# 19                          [Arabic]  https://restcountries.eu/data/kwt.svg
# 20                 [Kyrgyz, Russian]  https://restcountries.eu/data/kgz.svg
# 21                             [Lao]  https://restcountries.eu/data/lao.svg
# 22                  [Arabic, French]  https://restcountries.eu/data/lbn.svg
# 23             [Chinese, Portuguese]  https://restcountries.eu/data/mac.svg
# 24                       [Malaysian]  https://restcountries.eu/data/mys.svg
# 25                          [Divehi]  https://restcountries.eu/data/mdv.svg
# 26                       [Mongolian]  https://restcountries.eu/data/mng.svg
# 27                         [Burmese]  https://restcountries.eu/data/mmr.svg
# 28                          [Nepali]  https://restcountries.eu/data/npl.svg
# 29                          [Korean]  https://restcountries.eu/data/prk.svg
# 30                          [Arabic]  https://restcountries.eu/data/omn.svg
# 31                   [English, Urdu]  https://restcountries.eu/data/pak.svg
# 32                          [Arabic]  https://restcountries.eu/data/pse.svg
# 33                         [English]  https://restcountries.eu/data/phl.svg
# 34                          [Arabic]  https://restcountries.eu/data/qat.svg
# 35                          [Arabic]  https://restcountries.eu/data/sau.svg
# 36  [English, Malay, Tamil, Chinese]  https://restcountries.eu/data/sgp.svg
# 37                          [Korean]  https://restcountries.eu/data/kor.svg
# 38                [Sinhalese, Tamil]  https://restcountries.eu/data/lka.svg
# 39                          [Arabic]  https://restcountries.eu/data/syr.svg
# 40                         [Chinese]  https://restcountries.eu/data/twn.svg
# 41                  [Tajik, Russian]  https://restcountries.eu/data/tjk.svg
# 42                            [Thai]  https://restcountries.eu/data/tha.svg
# 43                      [Portuguese]  https://restcountries.eu/data/tls.svg
# 44                         [Turkish]  https://restcountries.eu/data/tur.svg
# 45                [Turkmen, Russian]  https://restcountries.eu/data/tkm.svg
# 46                          [Arabic]  https://restcountries.eu/data/are.svg
# 47                  [Uzbek, Russian]  https://restcountries.eu/data/uzb.svg
# 48                      [Vietnamese]  https://restcountries.eu/data/vnm.svg
# 49                          [Arabic]  https://restcountries.eu/data/yem.svg
#
#                                         regionalBlocs cioc
# 0   [{'acronym': 'SAARC', 'name': 'South Asian Ass...  AFG
# 1   [{'acronym': 'EEU', 'name': 'Eurasian Economic...  ARM
# 2                                                  []  AZE
# 3   [{'acronym': 'AL', 'name': 'Arab League', 'oth...  BRN
# 4   [{'acronym': 'SAARC', 'name': 'South Asian Ass...  BAN
# 5   [{'acronym': 'SAARC', 'name': 'South Asian Ass...  BHU
# 6   [{'acronym': 'ASEAN', 'name': 'Association of ...  BRU
# 7   [{'acronym': 'ASEAN', 'name': 'Association of ...  CAM
# 8                                                  []  CHN
# 9                                                  []  GEO
# 10                                                 []  HKG
# 11  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  IND
# 12  [{'acronym': 'ASEAN', 'name': 'Association of ...  INA
# 13                                                 []  IRI
# 14  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  IRQ
# 15                                                 []  ISR
# 16                                                 []  JPN
# 17  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  JOR
# 18  [{'acronym': 'EEU', 'name': 'Eurasian Economic...  KAZ
# 19  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  KUW
# 20  [{'acronym': 'EEU', 'name': 'Eurasian Economic...  KGZ
# 21  [{'acronym': 'ASEAN', 'name': 'Association of ...  LAO
# 22  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  LIB
# 23                                                 []
# 24  [{'acronym': 'ASEAN', 'name': 'Association of ...  MAS
# 25  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  MDV
# 26                                                 []  MGL
# 27  [{'acronym': 'ASEAN', 'name': 'Association of ...  MYA
# 28  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  NEP
# 29                                                 []  PRK
# 30  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  OMA
# 31  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  PAK
# 32  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  PLE
# 33  [{'acronym': 'ASEAN', 'name': 'Association of ...  PHI
# 34  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  QAT
# 35  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  KSA
# 36  [{'acronym': 'ASEAN', 'name': 'Association of ...  SIN
# 37                                                 []  KOR
# 38  [{'acronym': 'SAARC', 'name': 'South Asian Ass...  SRI
# 39  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  SYR
# 40                                                 []  TPE
# 41                                                 []  TJK
# 42  [{'acronym': 'ASEAN', 'name': 'Association of ...  THA
# 43                                                 []  TLS
# 44                                                 []  TUR
# 45                                                 []  TKM
# 46  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  UAE
# 47                                                 []  UZB
# 48  [{'acronym': 'ASEAN', 'name': 'Association of ...  VIE
# 49  [{'acronym': 'AL', 'name': 'Arab League', 'oth...  YEM

# %%
asia['subregion'].value_counts()
# Out:
# Western Asia          17
# South-Eastern Asia    11
# Southern Asia          9
# Eastern Asia           8
# Central Asia           5
# Name: subregion, dtype: int64

# %%
asia['subregion'].unique()
# Out:
# array(['Southern Asia', 'Western Asia', 'South-Eastern Asia',
#        'Eastern Asia', 'Central Asia'], dtype=object)

# %%
sea=asia[asia['subregion']=='South-Eastern Asia']
sea
# Out:
#                              country callingCodes              capital region  \
# 6                  Brunei Darussalam        [673]  Bandar Seri Begawan   Asia
# 7                           Cambodia        [855]           Phnom Penh   Asia
# 12                         Indonesia         [62]              Jakarta   Asia
# 21  Lao People's Democratic Republic        [856]            Vientiane   Asia
# 24                          Malaysia         [60]         Kuala Lumpur   Asia
# 27                           Myanmar         [95]            Naypyidaw   Asia
# 33                       Philippines         [63]               Manila   Asia
# 36                         Singapore         [65]            Singapore   Asia
# 42                          Thailand         [66]              Bangkok   Asia
# 43                       Timor-Leste        [670]                 Dili   Asia
# 48                          Viet Nam         [84]                Hanoi   Asia
#
#              subregion  population                       latlng  \
# 6   South-Eastern Asia      411900          [4.5, 114.66666666]
# 7   South-Eastern Asia    15626444                [13.0, 105.0]
# 12  South-Eastern Asia   258705000                [-5.0, 120.0]
# 21  South-Eastern Asia     6492400                [18.0, 105.0]
# 24  South-Eastern Asia    31405416                 [2.5, 112.5]
# 27  South-Eastern Asia    51419420                 [22.0, 98.0]
# 33  South-Eastern Asia   103279800                [13.0, 122.0]
# 36  South-Eastern Asia     5535000          [1.36666666, 103.8]
# 42  South-Eastern Asia    65327652                [15.0, 100.0]
# 43  South-Eastern Asia     1167242  [-8.83333333, 125.91666666]
# 48  South-Eastern Asia    92700000  [16.16666666, 107.83333333]
#
#           demonym       area  gini                          timezones  \
# 6        Bruneian     5765.0   NaN                        [UTC+08:00]
# 7       Cambodian   181035.0  37.9                        [UTC+07:00]
# 12     Indonesian  1904569.0  34.0  [UTC+07:00, UTC+08:00, UTC+09:00]
# 21        Laotian   236800.0  36.7                        [UTC+07:00]
# 24      Malaysian   330803.0  46.2                        [UTC+08:00]
# 27        Burmese   676578.0   NaN                        [UTC+06:30]
# 33       Filipino   342353.0  43.0                        [UTC+08:00]
# 36    Singaporean      710.0  48.1                        [UTC+08:00]
# 42           Thai   513120.0  40.0                        [UTC+07:00]
# 43  East Timorese    14874.0  31.9                        [UTC+09:00]
# 48     Vietnamese   331212.0  35.6                        [UTC+07:00]
#
#                       borders                nativeName  \
# 6                       [MYS]  Negara Brunei Darussalam
# 7             [LAO, THA, VNM]                 Kâmpŭchéa
# 12            [TLS, MYS, PNG]                 Indonesia
# 21  [MMR, KHM, CHN, THA, VNM]                    ສປປລາວ
# 24            [BRN, IDN, THA]                  Malaysia
# 27  [BGD, CHN, IND, LAO, THA]                    Myanma
# 33                         []                 Pilipinas
# 36                         []                 Singapore
# 42       [MMR, KHM, LAO, MYS]                 ประเทศไทย
# 43                      [IDN]               Timor-Leste
# 48            [KHM, CHN, LAO]                  Việt Nam
#
#                                 currencies                         languages  \
# 6        [Brunei dollar, Singapore dollar]                           [Malay]
# 7   [Cambodian riel, United States dollar]                           [Khmer]
# 12                     [Indonesian rupiah]                      [Indonesian]
# 21                               [Lao kip]                             [Lao]
# 24                     [Malaysian ringgit]                       [Malaysian]
# 27                          [Burmese kyat]                         [Burmese]
# 33                       [Philippine peso]                         [English]
# 36       [Brunei dollar, Singapore dollar]  [English, Malay, Tamil, Chinese]
# 42                             [Thai baht]                            [Thai]
# 43            [United States dollar, None]                      [Portuguese]
# 48                       [Vietnamese đồng]                      [Vietnamese]
#
#                                      flag  \
# 6   https://restcountries.eu/data/brn.svg
# 7   https://restcountries.eu/data/khm.svg
# 12  https://restcountries.eu/data/idn.svg
# 21  https://restcountries.eu/data/lao.svg
# 24  https://restcountries.eu/data/mys.svg
# 27  https://restcountries.eu/data/mmr.svg
# 33  https://restcountries.eu/data/phl.svg
# 36  https://restcountries.eu/data/sgp.svg
# 42  https://restcountries.eu/data/tha.svg
# 43  https://restcountries.eu/data/tls.svg
# 48  https://restcountries.eu/data/vnm.svg
#
#                                         regionalBlocs cioc
# 6   [{'acronym': 'ASEAN', 'name': 'Association of ...  BRU
# 7   [{'acronym': 'ASEAN', 'name': 'Association of ...  CAM
# 12  [{'acronym': 'ASEAN', 'name': 'Association of ...  INA
# 21  [{'acronym': 'ASEAN', 'name': 'Association of ...  LAO
# 24  [{'acronym': 'ASEAN', 'name': 'Association of ...  MAS
# 27  [{'acronym': 'ASEAN', 'name': 'Association of ...  MYA
# 33  [{'acronym': 'ASEAN', 'name': 'Association of ...  PHI
# 36  [{'acronym': 'ASEAN', 'name': 'Association of ...  SIN
# 42  [{'acronym': 'ASEAN', 'name': 'Association of ...  THA
# 43                                                 []  TLS
# 48  [{'acronym': 'ASEAN', 'name': 'Association of ...  VIE

# %%
#The most populous country in South-Eastern Asia
sea[sea['population']==sea['population'].max()]
# Out:
#       country callingCodes  capital region           subregion  population  \
# 12  Indonesia         [62]  Jakarta   Asia  South-Eastern Asia   258705000
#
#            latlng     demonym       area  gini  \
# 12  [-5.0, 120.0]  Indonesian  1904569.0  34.0
#
#                             timezones          borders nativeName  \
# 12  [UTC+07:00, UTC+08:00, UTC+09:00]  [TLS, MYS, PNG]  Indonesia
#
#              currencies     languages                                   flag  \
# 12  [Indonesian rupiah]  [Indonesian]  https://restcountries.eu/data/idn.svg
#
#                                         regionalBlocs cioc
# 12  [{'acronym': 'ASEAN', 'name': 'Association of ...  INA

# %%
#The least populous country
sea[sea['population']==sea['population'].min()]
# Out:
#              country callingCodes              capital region  \
# 6  Brunei Darussalam        [673]  Bandar Seri Begawan   Asia
#
#             subregion  population               latlng   demonym    area  \
# 6  South-Eastern Asia      411900  [4.5, 114.66666666]  Bruneian  5765.0
#
#    gini    timezones borders                nativeName  \
# 6   NaN  [UTC+08:00]   [MYS]  Negara Brunei Darussalam
#
#                           currencies languages  \
# 6  [Brunei dollar, Singapore dollar]   [Malay]
#
#                                     flag  \
# 6  https://restcountries.eu/data/brn.svg
#
#                                        regionalBlocs cioc
# 6  [{'acronym': 'ASEAN', 'name': 'Association of ...  BRU
